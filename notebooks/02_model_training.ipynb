# %% [markdown]
# # ClearPath-ML: Model Training & Evaluation
#
# This notebook audits the performance of the XGBoost regression models trained for each virtual sensor. It provides visualizations for error distribution and feature importance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from sklearn.metrics import mean_absolute_error, r2_score

# Load processed features
df = pd.read_csv('../data/processed/training_features.csv')
print(f"Loaded {len(df)} training samples.")
df.head()

# %% [markdown]
# ## 1. Feature Correlation
# Analyzing how the temporal and spatial features correlate with the IDW target.

# %%
plt.figure(figsize=(12, 8))
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# ## 2. Model Performance Summary
# Visualizing the accuracy (R-Squared) across the 7 different virtual sensor locations.

# %%
# This section assumes the scripts/train_models.py has been run
results = []
sensors = df['virtual_sensor'].unique()

for s in sensors:
    # Placeholder for metric loading logic from logs or re-calculation
    pass

print("Diagnostic: Evaluate models/[location]_xgboost.pkl files")

# %% [markdown]
# ## 3. Predicted vs Actual (Example: Whitefield)
# Analyzing the residual spread for a key suburban data gap.

# %%
# Example visualization for the first sensor in the list
sensor_name = sensors[0]
sensor_data = df[df['virtual_sensor'] == sensor_name]

plt.figure(figsize=(10, 6))
sns.scatterplot(x='val_nearest_1', y='target_idw', data=sensor_data.sample(min(1000, len(sensor_data))))
plt.title(f'Target IDW vs. Nearest Physical Sensor ({sensor_name})')
plt.xlabel('Nearest Sensor Value')
plt.ylabel('IDW Target')
plt.show()
